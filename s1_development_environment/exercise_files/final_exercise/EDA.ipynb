# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train1 = np.load("../../../data/corruptmnist/train_0.npz", mmap_mode='r')

# %%
train1.files
# Out:
# ['images', 'labels', 'allow_pickle']

# %%
images1 = train1['images']
labels1 = train1['labels']

# %%
plt.imshow(images1[700])

# %%
test = np.load("../../../data/corruptmnist/test.npz", mmap_mode='r')

# %%
test_images = test['images']

# %%
plt.imshow(test_images[1])
